# %%
import csv
import types
file=open('/content/J1 - Sheet1.csv','r')
data=list(csv.reader(file,delimiter=","))
file.close()
print(data)
print(type(data))
print(data[0])
# Out:
# [['C121', 'Snavi', 'Pune', '4-12-2002', 'J1', 'Manager', '100000', 'MBA'], ['C123', 'Murunmayee', 'Nashik', '25-1-2002', 'J2', 'Sr.Manager', '150000', 'MBA'], ['C124', 'Gayatri', 'Mumbai', '24-4-2005', 'J3', 'Manager', '90500', 'MBA'], ['C125', 'Shambhavi', 'Nashik', '2-2-1999', 'J4', 'Sr.Manager', '100500', 'MBA'], ['C126', 'Arnika', 'Pune', '2-2-1998', 'J5', 'Supervisor', '85000', 'B Tech']]
# <class 'list'>
# ['C121', 'Snavi', 'Pune', '4-12-2002', 'J1', 'Manager', '100000', 'MBA']

# %%
jobd=[]
for i in range(len(data)):
  jobd.append(data[i][5])
  print(jobd)
# Out:
# ['Manager']
# ['Manager', 'Sr.Manager']
# ['Manager', 'Sr.Manager', 'Manager']
# ['Manager', 'Sr.Manager', 'Manager', 'Sr.Manager']
# ['Manager', 'Sr.Manager', 'Manager', 'Sr.Manager', 'Supervisor']

# %%
empname=[]
for i in range(len(data)):
  empname.append(data[1][1])
  print("name joined on highest sal is",max(sal))
# Out:
# name joined on highest sal is Murunmayee
# name joined on highest sal is Murunmayee
# name joined on highest sal is Murunmayee
# name joined on highest sal is Murunmayee
# name joined on highest sal is Murunmayee

# %%
empname=[]
for i in range(len(data)):
  empname.append(data[1][4])
  print("name of employee no done mba",(name))
# Out:
# name of employee no done mba ['Snavi', 'Murunmayee', 'Gayatri', 'Shambhavi', 'Arnika', 'Snavi', 'Murunmayee', 'Gayatri', 'Shambhavi', 'Arnika', 'Snavi', 'Murunmayee', 'Gayatri', 'Shambhavi', 'Arnika']
# name of employee no done mba ['Snavi', 'Murunmayee', 'Gayatri', 'Shambhavi', 'Arnika', 'Snavi', 'Murunmayee', 'Gayatri', 'Shambhavi', 'Arnika', 'Snavi', 'Murunmayee', 'Gayatri', 'Shambhavi', 'Arnika']
# name of employee no done mba ['Snavi', 'Murunmayee', 'Gayatri', 'Shambhavi', 'Arnika', 'Snavi', 'Murunmayee', 'Gayatri', 'Shambhavi', 'Arnika', 'Snavi', 'Murunmayee', 'Gayatri', 'Shambhavi', 'Arnika']
# name of employee no done mba ['Snavi', 'Murunmayee', 'Gayatri', 'Shambhavi', 'Arnika', 'Snavi', 'Murunmayee', 'Gayatri', 'Shambhavi', 'Arnika', 'Snavi', 'Murunmayee', 'Gayatri', 'Shambhavi', 'Arnika']
# ...

# %%
employees=[]
manager_count=[]
def count_managers(employees):
  count=0
  for employee in employees:
    if employee["designation"].lower()=="manager":
      count+=1
      return count
      employee=[]
managers_count=count_managers(employees)
print("number of employees with the designation manager:",manager_count)
# Out:
# number of employees with the designation manager: []

# %%
employees=[]
'count_employee_starting_with_s'==[]
'num_employees_starting_with_s'==[]
def count_employee_starting_with_s(names):
  count=0
  for name in names:
    if name.lower().startswith('s'):
      count+=1
      return count
      employee_names=[sanvi,mrunmayee,gayatri,shambhavi,arnika]
num_employees_starting_with_s == count_employees_starting_with_s(employee_names)
print("number of employees starting with's':",num_employees_starting_with_s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-49ecde74cf18> in <cell line: 11>()
#       9       return count
#      10       employee_names=[sanvi,mrunmayee,gayatri,shambhavi,arnika]
# ---> 11 num_employees_starting_with_s == count_employees_starting_with_s(employee_names)
#      12 print("number of employees starting with's':",num_employees_starting_with_s)
#
# NameError: name 'count_employees_starting_with_s' is not defined
